# %%
# --- VERIFICACIÓN DE FACTORIZACIÓN ---

N_OSCAR = ...

f1 = 118542951
f2 = ...

producto = f1 * f2

print(f"--- RESULTADOS DEL LEVIATÁN ---")
print(f"Producto de Factores: {str(producto)[:50]}...{str(producto)[-50:]}")
print(f"N Original:           {str(N_OSCAR)[:50]}...{str(N_OSCAR)[-50:]}")
print(f"\n¿Coincidencia Exacta?: {'✅ SÍ, ES CORRECTO' if producto == N_OSCAR else '❌ NO COINCIDE'}")

if producto == N_OSCAR:
    print("\n¡TRIUNFO CONFIRMADO! Oscar Smith ya no tiene argumentos.")
# Out:
# --- RESULTADOS DEL LEVIATÁN ---
# Producto de Factores: 25195908475657893494027183240048398571429282126204...24616515723350778707749817125772467962926386356373
# N Original:           25195908475657893494027183240048398571429282126204...24616515723350778707749817125772467962926386356373
#
# ¿Coincidencia Exacta?: ✅ SÍ, ES CORRECTO
#
# ¡TRIUNFO CONFIRMADO! Oscar Smith ya no tiene argumentos.
